# %% [markdown]
# # Netflix Data Exploration Project

# %% [markdown]
# ## Load data into a dictionary

# %%
years  = [i for i in range(2011, 2021)]
durations = [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]
print(years)
print(durations)
# Out:
# [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]

# %%
movie_dict = {'years':years, 'durations':durations}
print(movie_dict)
# Out:
# {'years': [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], 'durations': [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]}

# %% [markdown]
# ## Creating a dataframe from a Dictionary

# %%
import pandas as pd 
durations_df = pd.DataFrame(movie_dict)
print(durations_df)
# Out:
#    years  durations
# 0   2011        103
# 1   2012        101
# 2   2013         99
# 3   2014        100
# 4   2015        100
# 5   2016         95
# 6   2017         95
# 7   2018         96
# 8   2019         93
# 9   2020         90

# %% [markdown]
# ## Visual insepction of data

# %%
import matplotlib.pyplot as plt
fig =  plt.figure()

# %%
# Creating a line graph showing year vs duration trend
plt.plot(durations_df['years'], durations_df['durations'])
plt.xlabel('Year released')
plt.ylabel('Duration of film')
plt.title('Duration of movies over the years')
plt.show()

# %% [markdown]
# ## Load Data from csv file

# %%
import pandas as pd
netflix_df = pd.read_csv('/Users/joseservin/DataCamp/Projects/netflix_titles.csv')
netflix_df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ### Subset netflix_df for type = 'Movie'

# %%
netflix_df_movies_only = netflix_df.loc[netflix_df['type'] == 'Movie']
netflix_df_movies_only
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %% [markdown]
# ### Select certain columns in netflix_df_movies_only

# %%
# Create new df with columns title, country, listed_in, release_year and duration from netflix_df_movies_only df
netflix_movies_col_subset = netflix_df_movies_only[['title','country','listed_in','release_year','duration']]
netflix_movies_col_subset.head(5)
# Out:
#                                title  \
# 0               Dick Johnson Is Dead
# 6   My Little Pony: A New Generation
# 7                            Sankofa
# 9                       The Starling
# 12                      Je Suis Karl
#
#                                               country  \
# 0                                       United States
# 6                                                 NaN
# 7   United States, Ghana, Burkina Faso, United Kin...
# 9                                       United States
# 12                            Germany, Czech Republic
#
#                                            listed_in  release_year duration
# 0                                      Documentaries          2020   90 min
# 6                           Children & Family Movies          2021   91 min
# 7   Dramas, Independent Movies, International Movies          1993  125 min
# 9                                   Comedies, Dramas          2021  104 min
# ...

# %% [markdown]
# ### Creating a scatter plot with new netflix_movies_col_subset data

# %% [markdown]
# #### First we'll need to check data types

# %%
netflix_movies_col_subset.dtypes
# Out:
# title           object
# country         object
# listed_in       object
# release_year     int64
# duration        object
# dtype: object

# %% [markdown]
# #### Convert duration to int data type

# %%
# remove 'min' from row data
netflix_movies_col_subset['duration'] =  netflix_movies_col_subset['duration'].str[:-3]
# Out:
# /var/folders/77/ysxyzr2j3zdb588cls576tc00000gn/T/ipykernel_19340/3752005981.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_movies_col_subset['duration'] =  netflix_movies_col_subset['duration'].str[:-3]

# %%
netflix_movies_col_subset
# Out:
#                                  title  \
# 0                 Dick Johnson Is Dead
# 6     My Little Pony: A New Generation
# 7                              Sankofa
# 9                         The Starling
# 12                        Je Suis Karl
# ...                                ...
# 8801                           Zinzana
# 8802                            Zodiac
# 8804                        Zombieland
# 8805                              Zoom
# 8806                            Zubaan
#
#                                                 country  \
# 0                                         United States
# 6                                                   NaN
# 7     United States, Ghana, Burkina Faso, United Kin...
# 9                                         United States
# 12                              Germany, Czech Republic
# ...                                                 ...
# 8801                       United Arab Emirates, Jordan
# ...

# %%
# check for Null values in duration column
netflix_movies_col_subset[netflix_movies_col_subset['duration'].isnull()]
# Out:
#                                      title        country listed_in  \
# 5541                       Louis C.K. 2017  United States    Movies
# 5794                 Louis C.K.: Hilarious  United States    Movies
# 5813  Louis C.K.: Live at the Comedy Store  United States    Movies
#
#       release_year duration
# 5541          2017      NaN
# 5794          2010      NaN
# 5813          2015      NaN

# %%
# redefine netflix_movies_col_subset to be that of which duration column IS NOT NULL
netflix_movies_col_subset = netflix_movies_col_subset[netflix_movies_col_subset['duration'].notnull()]

# %%
# check that no more NULL values exist in netflix_movies_col_subset
netflix_movies_col_subset[netflix_movies_col_subset['duration'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, country, listed_in, release_year, duration]
# Index: []

# %%
# convert duration column to integers (we first got an error because we have null values in our DataFrame)
netflix_movies_col_subset=  netflix_movies_col_subset.astype({'duration':int})

# %%
fig = plt.figure(figsize=(20,15))

# create a scatter plot with duration versus year
plt.scatter(netflix_movies_col_subset['release_year'], netflix_movies_col_subset['duration'])

# Create a title 
plt.title('Duration of movies over the Years')

# show the plot
plt.show()

# %% [markdown]
# ## Digging deeper

# %%
# filter data to include movies that are less than 60 minutes long (examine the short films)
netflix_movies_col_subset.describe()
# Out:
#        release_year     duration
# count   6128.000000  6128.000000
# mean    2013.121084    99.577187
# std        9.680300    28.290593
# min     1942.000000     3.000000
# 25%     2012.000000    87.000000
# 50%     2016.000000    98.000000
# 75%     2018.000000   114.000000
# max     2021.000000   312.000000

# %% [markdown]
# ### Creating short movie DataFrame

# %%
short_films = netflix_movies_col_subset.loc[netflix_movies_col_subset['duration'] < 60 ]

# %%
short_films.head(20)
# Out:
#                                                  title               country  \
# 45                              My Heroes Were Cowboys                   NaN
# 71                         A StoryBots Space Adventure                   NaN
# 77                       Little Singham - Black Shadow                   NaN
# 279               Monster Hunter: Legends of the Guild  United States, Japan
# 470                        Bridgerton - The Afterparty                   NaN
# 484                       Lee Su-geun: The Sense Coach                   NaN
# 495                                          Awon Boyz                   NaN
# 560                                            Audible                   NaN
# 694                                              Aziza        Lebanon, Syria
# 695                                     Besieged Bread                   NaN
# 729                      Bling Empire - The Afterparty                   NaN
# ...

# %% [markdown]
# ### Marking non-feature films

# %%
# First start by seeing unique values in listed_in column
netflix_movies_col_subset.listed_in.unique()

# children (red) , documentaries (blue), stand-up (green ) else black
# Out:
# array(['Documentaries', 'Children & Family Movies',
#        'Dramas, Independent Movies, International Movies',
#        'Comedies, Dramas', 'Dramas, International Movies',
#        'Children & Family Movies, Comedies',
#        'Documentaries, International Movies', 'Thrillers',
#        'Comedies, International Movies',
#        'Comedies, International Movies, Romantic Movies',
#        'Comedies, International Movies, Music & Musicals', 'Comedies',
#        'Horror Movies, Sci-Fi & Fantasy',
#        'Dramas, International Movies, Thrillers',
#        'Action & Adventure, Dramas, International Movies',
#        'Action & Adventure, Dramas',
#        'Action & Adventure, Classic Movies, Dramas',
#        'Dramas, Horror Movies, Thrillers',
#        'Action & Adventure, Horror Movies, Thrillers',
#        'Action & Adventure', 'Dramas, Thrillers',
#        'Action & Adventure, Anime Features, International Movies',
#        'Documentaries, International Movies, Sports Movies',
# ...

# %%
# Using a for loop through netflix_movies_col_subset and specify color for desired listed_in (genre)
colors = []
for lab, row in netflix_movies_col_subset.iterrows():
    if row['listed_in'] == 'Documentaries':
        colors.append('blue')
    elif row['listed_in'] == 'Children & Family Movies':
        colors.append('red')
    elif row['listed_in'] == 'Stand-Up':
        colors.append('red')
    else:
        colors.append('black')
print(colors[:11])
# Out:
# ['blue', 'red', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'red', 'black']

# %% [markdown]
# ### Plotting non-feature films

# %%
# Set the figure style and initalize a new figure
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus release_year
plt.scatter(netflix_movies_col_subset['release_year'], netflix_movies_col_subset['duration'], c=colors)

# Create a title and axis labels
plt.title('Movie duration by year of release')
plt.xlabel('Release year')
plt.ylabel("Duration (min)")
plt.show()

# %%
# Visually we can see that filtered genres weight down average therefore we need to explore the data more in order to answer the question: are movies getting shorter?
