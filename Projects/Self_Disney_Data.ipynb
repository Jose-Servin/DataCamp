# %%
import pandas as pd

# %% [markdown]
# # Step 1: Import and Inspect Data

# %%
disney_data = pd.read_csv('/Users/joseservin/DataCamp/Projects/disney_plus_titles.csv')
disney_data.head(10)
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
# 5      s6    Movie                                 Becoming Cousteau
# 6      s7  TV Show                                           Hawkeye
# 7      s8  TV Show                            Port Protection Alaska
# 8      s9  TV Show                         Secrets of the Zoo: Tampa
# 9     s10    Movie             A Muppets Christmas: Letters To Santa
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# ...

# %%
disney_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 136.1+ KB

# %%
disney_data.shape
# Out:
# (1450, 12)

# %%
# describe method provides stats for columns with numeric data types
disney_data.describe()
# Out:
#        release_year
# count   1450.000000
# mean    2003.091724
# std       21.860162
# min     1928.000000
# 25%     1999.000000
# 50%     2011.000000
# 75%     2018.000000
# max     2021.000000

# %% [markdown]
# ## Inspect DataFrame components (values, columns, index)

# %%
disney_data.values
# Out:
# array([['s1', 'Movie',
#         'Duck the Halls: A Mickey Mouse Christmas Special', ...,
#         '23 min', 'Animation, Family',
#         'Join Mickey and the gang as they duck the halls!'],
#        ['s2', 'Movie', 'Ernest Saves Christmas', ..., '91 min', 'Comedy',
#         'Santa Claus passes his magic bag to a new St. Nic.'],
#        ['s3', 'Movie', 'Ice Age: A Mammoth Christmas', ..., '23 min',
#         'Animation, Comedy, Family',
#         "Sid the Sloth is on Santa's naughty list."],
#        ...,
#        ['s1448', 'Movie', 'Eddie the Eagle', ..., '107 min',
#         'Biographical, Comedy, Drama',
#         'True story of Eddie Edwards, a British ski-jumper whose Olympic performance wins the hearts of fans.'],
#        ['s1449', 'Movie', 'Bend It Like Beckham', ..., '112 min',
#         'Buddy, Comedy, Coming of Age',
#         'Despite the wishes of their traditional families, two girls aim for careers in professional soccer.'],
# ...

# %%
disney_data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
disney_data.index
# Out:
# RangeIndex(start=0, stop=1450, step=1)

# %% [markdown]
# # Step 2: Sorting and Subsetting

# %% [markdown]
# ## Sorting by ascending column

# %%
disney_data.sort_values('release_year')
# Out:
#      show_id     type                                   title  \
# 1220   s1221    Movie                        Steamboat Willie
# 893     s894    Movie                       Flowers and Trees
# 1178   s1179    Movie                        Santa's Workshop
# 736     s737    Movie                      Babes in the Woods
# 1317   s1318    Movie                          The Pied Piper
# ...      ...      ...                                     ...
# 148     s149  TV Show                   Mickey Mouse Funhouse
# 145     s146  TV Show                Chip 'n' Dale: Park Life
# 143     s144    Movie  Built for Mars: The Perseverance Rover
# 139     s140    Movie            Killer Shark vs Killer Whale
# 158     s159  TV Show                   Behind the Attraction
#
#                     director  \
# 1220  Walt Disney, Ub Iwerks
# 893             Burt Gillett
# 1178         Wilfred Jackson
# 736             Burt Gillett
# 1317         Wilfred Jackson
# ...                      ...
# ...

# %% [markdown]
# ## Sorting by descending column

# %%
disney_data.sort_values('release_year', ascending=False)
# Out:
#      show_id     type                                   title  \
# 155     s156    Movie                                Stuntman
# 315     s316  TV Show                             WandaVision
# 139     s140    Movie            Killer Shark vs Killer Whale
# 141     s142  TV Show   Cesar Millan: Better Human Better Dog
# 143     s144    Movie  Built for Mars: The Perseverance Rover
# ...      ...      ...                                     ...
# 1362   s1363    Movie                       Three Little Pigs
# 736     s737    Movie                      Babes in the Woods
# 1178   s1179    Movie                        Santa's Workshop
# 893     s894    Movie                       Flowers and Trees
# 1220   s1221    Movie                        Steamboat Willie
#
#                     director  \
# 155             Kurt Mattila
# 315                      NaN
# 139                      NaN
# 141                      NaN
# 143             Mark J Davis
# ...                      ...
# ...

# %% [markdown]
# ## Sorting by multiple columns

# %%
disney_data.sort_values(['release_year', 'title'], ascending=[False,True])
# Out:
#      show_id     type                                           title  \
# 235     s236    Movie                                    22 vs. Earth
# 93       s94    Movie                                   A Spark Story
# 14       s15    Movie                           America the Beautiful
# 132     s133  TV Show  America's Funniest Home Videos: Animal Edition
# 207     s208    Movie                                    American Eid
# ...      ...      ...                                             ...
# 1418   s1419    Movie                                   Ye Olden Days
# 736     s737    Movie                              Babes in the Woods
# 893     s894    Movie                               Flowers and Trees
# 1178   s1179    Movie                                Santa's Workshop
# 1220   s1221    Movie                                Steamboat Willie
#
#                         director  \
# 235                Kevin Nolting
# 93    Jason Sterman, Leanne Dare
# ...

# %% [markdown]
# ## Subsetting multiple columns

# %%
disney_data[['title','release_year','type']]
# Out:
#                                                  title  release_year     type
# 0     Duck the Halls: A Mickey Mouse Christmas Special          2016    Movie
# 1                               Ernest Saves Christmas          1988    Movie
# 2                         Ice Age: A Mammoth Christmas          2011    Movie
# 3                           The Queen Family Singalong          2021    Movie
# 4                                The Beatles: Get Back          2021  TV Show
# ...                                                ...           ...      ...
# 1445                          X-Men Origins: Wolverine          2009    Movie
# 1446    Night at the Museum: Battle of the Smithsonian          2009    Movie
# 1447                                   Eddie the Eagle          2016    Movie
# 1448                              Bend It Like Beckham          2003    Movie
# 1449             Captain Sparky vs. The Flying Saucers          2012    Movie
#
# [1450 rows x 3 columns]

# %% [markdown]
# ## Subsetting rows

# %%
disney_data[disney_data['release_year'] >= 2010]
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# 5         s6    Movie                                 Becoming Cousteau
# ...      ...      ...                                               ...
# 1439   s1440  TV Show                              Disney Kirby Buckets
# 1440   s1441  TV Show                                    Disney Mech-X4
# 1442   s1443    Movie                                      Tomorrowland
# 1447   s1448    Movie                                   Eddie the Eagle
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
disney_data[disney_data['type'] == 'TV Show']
# Out:
#      show_id     type                      title director  \
# 4         s5  TV Show      The Beatles: Get Back      NaN
# 6         s7  TV Show                    Hawkeye      NaN
# 7         s8  TV Show     Port Protection Alaska      NaN
# 8         s9  TV Show  Secrets of the Zoo: Tampa      NaN
# 13       s14  TV Show      Dr. Oakley, Yukon Vet      NaN
# ...      ...      ...                        ...      ...
# 1417   s1418  TV Show           X-Men: Evolution      NaN
# 1434   s1435  TV Show                  Smart Guy      NaN
# 1439   s1440  TV Show       Disney Kirby Buckets      NaN
# 1440   s1441  TV Show             Disney Mech-X4      NaN
# 1441   s1442  TV Show         Imagination Movers      NaN
#
#                                                    cast        country  \
# 4     John Lennon, Paul McCartney, George Harrison, ...            NaN
# 6     Jeremy Renner, Hailee Steinfeld, Vera Farmiga,...            NaN
# ...

# %%
disney_data[(disney_data['release_year'] >= 2019) & (disney_data['type'] == 'TV Show')]
# Out:
#      show_id     type                                 title director  \
# 4         s5  TV Show                 The Beatles: Get Back      NaN
# 6         s7  TV Show                               Hawkeye      NaN
# 8         s9  TV Show             Secrets of the Zoo: Tampa      NaN
# 18       s19  TV Show                    Disney Intertwined      NaN
# 28       s29  TV Show                         Olaf Presents      NaN
# ...      ...      ...                                   ...      ...
# 1060   s1061  TV Show                 Marvel's Hero Project      NaN
# 1134   s1135  TV Show                    Pixar In Real Life      NaN
# 1213   s1214  TV Show                      Star Wars: Blips      NaN
# 1288   s1289  TV Show                The Imagineering Story      NaN
# 1358   s1359  TV Show  The World According to Jeff Goldblum      NaN
#
#                                                    cast        country  \
# ...

# %% [markdown]
# ## Subsetting categorical data based on two or more conditions

# %%
disney_data.rating.unique()
# Out:
# array(['TV-G', 'PG', 'TV-PG', nan, 'PG-13', 'TV-14', 'G', 'TV-Y7', 'TV-Y',
#        'TV-Y7-FV'], dtype=object)

# %%
# using the isin() method on categorical columns
disney_data[disney_data['rating'].isin(['PG','TV_PG'])]
# Out:
#      show_id   type                                           title  \
# 1         s2  Movie                          Ernest Saves Christmas
# 19       s20  Movie                                       Enchanted
# 23       s24  Movie                           Home Sweet Home Alone
# 43       s44  Movie                              Jingle All The Way
# 44       s45  Movie                            Jingle All the Way 2
# ...      ...    ...                                             ...
# 1438   s1439  Movie                                 Those Calloways
# 1442   s1443  Movie                                    Tomorrowland
# 1443   s1444  Movie                                      Aquamarine
# 1444   s1445  Movie                  Ice Age: Dawn Of The Dinosaurs
# 1446   s1447  Movie  Night at the Museum: Battle of the Smithsonian
#
#                        director  \
# 1                   John Cherry
# 19                   Kevin Lima
# 23                    Dan Mazer
# ...

# %% [markdown]
# # Step 3: Transforming DataFrames: creating new columns
