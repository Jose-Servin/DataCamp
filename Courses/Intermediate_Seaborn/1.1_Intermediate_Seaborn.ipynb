# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# %% [markdown]
# # Seaborn Review

# %%
df = pd.read_csv('/Users/joseservin/DataCamp/Courses/Intro_Seaborn/mpg.csv')

# %%
df['horsepower'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# * By defualt, the distplot generates a Gaussian Kernal Density Estimate (KDE)

# %%
sns.distplot(df['horsepower'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %% [markdown]
# # Using the Distribution Plot

# %% [markdown]
# ## Creating a standard Histogram

# %%
sns.distplot(df['horsepower'], kde=False, bins=10)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower'>

# %% [markdown]
# ## Alternative data distributions

# %% [markdown]
# * A rug plot is an alternative way to view the distribution of data

# %%
sns.distplot(df['horsepower'], kde=False, rug=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower'>

# %%
sns.distplot(df['horsepower'], kde=True, kde_kws={'shade':True})
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %% [markdown]
# # Regression Plots in Seaborn

# %% [markdown]
# * The regplot function generates a scatter plot with a regression line.
# * The data, x and y variables must be defined.

# %%
sns.regplot(data=df, x='displacement', y='horsepower')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %% [markdown]
# ## sns.lmplot() represents a higher level plot for the regplot()

# %% [markdown]
# * Faceting is the use of plotting multiple graphs while changing a single variable

# %%
sns.lmplot(data=df, x='displacement', y='horsepower', col='origin')

# %%
sns.lmplot(data=df, x='displacement', y='horsepower', hue='origin')

# %% [markdown]
# # Using Seaborn Styles

# %% [markdown]
# ## Seaborn default configurations: dark grid

# %%
sns.set()

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df['model_year'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.histplot(df, x='model_year')
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='Count'>

# %% [markdown]
# ## Theme examples with sns.set_style()

# %%
for style in ['white','dark','whitegrid','darkgrid','ticks']:
    sns.set_style(style)
    sns.distplot(df['horsepower'])
    plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Removing axes with despine()

# %% [markdown]
# * by default, top and right lines are removed

# %%
sns.distplot(df['horsepower'])
sns.despine(left=True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Colors in Seaborn

# %% [markdown]
# * Seaborn supports Matplotlib color codes by passing color_codes=True to sns.set()

# %%
sns.set(color_codes=True)
sns.distplot(df['horsepower'], color='g')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %% [markdown]
# ## Color Pallets

# %%
for p in sns.palettes.SEABORN_PALETTES:
    print(p)
# Out:
# deep
# deep6
# muted
# muted6
# pastel
# pastel6
# bright
# bright6
# dark
# dark6
# colorblind
# colorblind6

# %% [markdown]
# ## Displaying Palettes

# %% [markdown]
# * sns_palplot() function displays the palette
# * sns.color_palette() returns the current palette

# %%
for p in sns.palettes.SEABORN_PALETTES:
    sns.set_palette(p)
    sns.palplot(sns.color_palette())
    plt.show()

# %% [markdown]
# ## Defining Custom Palettes

# %% [markdown]
# ### Circular Palette: when data is not ordered

# %%
sns.palplot(
    sns.color_palette('Paired', 12) # 12 is the argument for number of colors returned
)

# %% [markdown]
# ### Sequential Palette: when the data has a consistant range from high to low

# %%
sns.palplot(
    sns.color_palette('Blues',12)
)

# %% [markdown]
# ### Diverging colors: when both the low and high values are interesting

# %%
sns.palplot(
    sns.color_palette('BrBG', 12)
)

# %% [markdown]
# ### setting custom palette to graph

# %%
sns.stripplot(data=df, y='origin', x='horsepower', jitter=True, palette='Paired')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='origin'>

# %% [markdown]
# # Customizing with matplotlib

# %% [markdown]
# ## matplotlib axes

# %% [markdown]
# * Axes can be passed to seaborn functions

# %%
fig, ax = plt.subplots()
sns.histplot(df['horsepower'], ax =ax) # matplotlib function passed to seaborn histplot() function 
ax.set(xlabel = 'Horsepower Distribution') # matplotlib function to set xlabel
# Out:
# [Text(0.5, 0, 'Horsepower Distribution')]

# %% [markdown]
# ## Further Customization

# %%
fig, ax = plt.subplots()
sns.histplot(df['horsepower'], ax =ax) # matplotlib function passed to seaborn histplot() function 
ax.set(
    xlabel = 'Horsepower Distribution',
    ylabel = 'Count',
    xlim=(50, 175),
    title='Histogram of Horsepower'
    ) # matplotlib function to set xlabel
# Out:
# [Text(0.5, 0, 'Horsepower Distribution'),
#  Text(0, 0.5, 'Count'),
#  (50.0, 175.0),
#  Text(0.5, 1.0, 'Histogram of Horsepower')]

# %% [markdown]
# # Combining Plots

# %%
df.origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
fig, (ax0, ax1) = plt.subplots(
    nrows=1, ncols=2, sharey=True, figsize = (7,4)
)

sns.histplot(df.query('origin == "usa"')['horsepower'], ax=ax0)
sns.histplot(df.query('origin == "japan"')['horsepower'], ax=ax1)

ax1.set(
    xlabel = 'Japan',
    title = 'Horsepower Histogram Japan'
)
ax1.axvline(x=80, label='Japan vline')
ax0.set(
    xlabel = 'USA',
    title = 'Horsepower Histogram USA'
)
ax0.axvline(x=110, label='USA vline')
ax1.legend()
ax0.legend()

# %% [markdown]
# # Combining Plots Part 2

# %%
usa_mean = df.query('origin == "usa"')['horsepower'].mean()

# %%
usa_median = df.query('origin == "usa"')['horsepower'].median()

# %%
fig, ax = plt.subplots()

sns.distplot(df.query('origin == "usa"')['horsepower'], ax=ax)
ax.set(
    xlabel = 'horesepower',
    title = 'USA Horsepower'
)

ax.axvline(x=usa_mean, label='mean')
ax.axvline
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <bound method Axes.axvline of <AxesSubplot:title={'center':'USA Horsepower'}, xlabel='horesepower', ylabel='Density'>>

# %% [markdown]
# # Categorical Plot Types

# %% [markdown]
# ## Show each observation: stripplot and swarmplot

# %% [markdown]
# ### stripplot

# %%
sns.stripplot(data=df, y='origin', x='horsepower', jitter=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='origin'>

# %% [markdown]
# ### swarmplot

# %% [markdown]
# * swarmplot does not scale well with large datasets

# %%
sns.swarmplot(data=df, x='origin', y='horsepower')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 10.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %% [markdown]
# ## Abstract Representations: boxplot, violinplot, lvplot

# %% [markdown]
# ### boxplot

# %%
sns.boxplot(data=df, x='origin', y='horsepower')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %% [markdown]
# ### violinplot: combination of box plot and Kernal Density Plot

# %% [markdown]
# * good option to use for large datasets but can be computationally intensive to create

# %%
sns.violinplot(data=df, x='origin', y='horsepower')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %% [markdown]
# ### lvplot (Letter Value Plot)

# %% [markdown]
# * scales more correctly in large datasets

# %% [markdown]
# ## Statistical Estimates: barplot, pointplot and countplot

# %% [markdown]
# ### barplot: shows summary measure and confidence interval

# %%
df.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
sns.barplot(data=df, x='origin', y='horsepower', hue='cylinders')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %%
sns.barplot(data=df, x='origin', y='horsepower')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %% [markdown]
# ### pointplot: shows summary measure and confidence interal

# %%
sns.pointplot(data=df, x='origin', y='horsepower')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %% [markdown]
# ### countplot: shows number of instances for each variable

# %%
sns.countplot(x='origin', data=df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='count'>

# %% [markdown]
# # Regression Plots

# %%
sns.regplot(data=df, x='displacement', y='horsepower')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %% [markdown]
# ## Evaluating a regression with residplot()

# %% [markdown]
# * A residual plot is useful for evaluating the fit of a model
# * can demonstrate the approrietness of a regressional plot
# * idealy, the residual values on the plot should be plotted randomly accross the horizontal line

# %%
sns.residplot(data=df, x='displacement',y='horsepower')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# * supported in regplot by the order parameter

# %%
sns.regplot(
    data=df,
    x='displacement',
    y='horsepower',
    order=2 # second order polynomial function
)
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %% [markdown]
# * supported in residplot() using the order parameter

# %%
sns.residplot(
    data=df,
    x='displacement',
    y='horsepower',
    order=2
)
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='horsepower'>

# %% [markdown]
# ## Regression plot and categorical values

# %%
sns.regplot(
    data=df,
    x='cylinders', # categorical value 
    y='horsepower',
    x_jitter=.1,
    order=2
)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %% [markdown]
# ### Regressino plot and Categorical Values with estimators

# %%
sns.regplot(
    data=df,
    x='cylinders', # categorical value 
    y='horsepower',
    x_estimator= np.mean,
    order=2
)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %% [markdown]
# ## Binning the data

# %% [markdown]
# * x_bins can be used to divide the data into discrete bins
# * the regression line is still fit against all the data

# %%
sns.regplot(
    data=df,
    x='cylinders', # categorical value 
    y='horsepower',
    x_bins=4
)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %% [markdown]
# # Matrix Plots

# %% [markdown]
# * most common type is the heat map
# * can be use to quickly see trends in the data

# %% [markdown]
# ## heatmap()

# %% [markdown]
# * requires data to be in a grid format
# * pandas crosstab() is used to manipulate data

# %%
df.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
pd.crosstab(
    df['model_year'],
    df['origin'],
    values=df['mpg'],
    aggfunc='mean'
).round(0)
# Out:
# origin      europe  japan   usa
# model_year
# 70            25.0   26.0  15.0
# 71            29.0   30.0  18.0
# 72            22.0   24.0  16.0
# 73            24.0   20.0  15.0
# 74            27.0   29.0  18.0
# 75            24.0   28.0  18.0
# 76            24.0   28.0  19.0
# 77            29.0   27.0  21.0
# 78            25.0   30.0  22.0
# 79            30.0   33.0  23.0
# 80            37.0   35.0  26.0
# 81            32.0   33.0  28.0
# 82            40.0   35.0  29.0

# %%
sns.heatmap(
    pd.crosstab(
    df['model_year'],
    df['origin'],
    values=df['mpg'],
    aggfunc='mean'
).round(0)
)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='model_year'>

# %% [markdown]
# ## Customize a heatmap

# %%
df_crosstab = pd.crosstab(
    df['model_year'],
    df['origin'],
    values=df['mpg'],
    aggfunc='mean'
).round(0)

# %%
sns.heatmap(
    df_crosstab,
    annot=True,  # shows values of individual cells 
    #fmt='d', # ensures results are displayed as integers 
    cmap='YlGnBu', # custom color map "cmap"
    cbar = False, # color bar 
    linewidths= 0.5 # places small spacing between the cells 
)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='model_year'>

# %% [markdown]
# ## Centering a Heatmap

# %% [markdown]
# * shifting the overall color scheme of the heatmap

# %%
sns.heatmap(
    df_crosstab,
    annot=True,  # shows values of individual cells 
    #fmt='d', # ensures results are displayed as integers 
    cmap='YlGnBu', # custom color map "cmap"
    cbar = False, # color bar 
    linewidths= 0.5, # places small spacing between the cells 
    center=df_crosstab.loc[82,'europe']
)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='model_year'>

# %% [markdown]
# # Plotting a correlation matrix

# %% [markdown]
# * pandas corr() function calculates correlations between columns in a dataframe

# %%
sns.heatmap(
    df.corr()
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Using FacetGrid, factorplot and Lmplot

# %% [markdown]
# ## Facetgrid

# %% [markdown]
# * The foundation of many data aware grids
# * Allows the user to control how data is distributed across columns, rows and hue
# * once a Facetgrid is created, the plot type must be mapped to the grid

# %% [markdown]
# ### Facetgrid categorical example

# %%
g = sns.FacetGrid(data=df, col='origin')
g.map(
    sns.boxplot,
    'horsepower',
    order = ['usa','japan','europe']
    )

# %% [markdown]
# ## Facetgrid for regression and scatter plots

# %%
g = sns.FacetGrid(data=df, col='origin') # col is the categorical variable 
g.map(plt.scatter, 'horsepower', 'displacement') # two numeric variables being compared on a scatter plot

# %%
g = sns.FacetGrid(data=df, col='origin') # col is the categorical variable 
g.map(sns.regplot, 'horsepower', 'displacement') # two numeric variables being compared on a scatter plot

# %% [markdown]
# ## lmplot (one step option)

# %% [markdown]
# * plots scatter and regression plots on a FacetGrid

# %%
sns.lmplot(
    data=df,
    col='origin',
    x='horsepower',
    y='displacement',
    fit_reg=False # disables regression line
)

# %% [markdown]
# ## Factorplot (one step option)

# %% [markdown]
# * a simpler way to use a FacetGrid for categorical data
# * combines Facetting and mapping process into 1 function

# %%
sns.factorplot(
    data = df,
    x='horsepower',
    col='origin',
    kind='box'
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ## FacetGrid Examples

# %%
g = sns.FacetGrid(
    data=df, 
    col='origin',
    col_order = ['usa','europe','japan']
)

g.map(
    sns.pointplot,
    'horsepower'
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/axisgrid.py:670: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## FacetorPlot Example

# %% [markdown]
# * The factorplot is often more convenient than using a FacetGrid for creating data aware grids.

# %%
sns.factorplot(
    data=df,
    x='horsepower',
    col='origin',
    kind= 'box',
    col_order = ['usa','europe','japan']
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ## FacetGrid scatter Example

# %%
g = sns.FacetGrid(
    data=df,
    col = 'origin',
    col_order= ['usa','europe','japan']
)

g.map(
    plt.scatter,
    'horsepower',
    'displacement'
)

# %% [markdown]
# ## lmplot Example

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.lmplot(
    data=df,
    col = 'origin',
    x='horsepower',
    y='displacement',
    col_order= ['usa','europe','japan'],
    fit_reg=False, 
    row='model_year'
)

# %% [markdown]
# # Using PairGrid and pairplot

# %% [markdown]
# ## PairGrid

# %% [markdown]
# * shows pairwise relationships between data elements
# * follows similar API to FacetGrid

# %%
g = sns.PairGrid(
    data=df,
    vars=['horsepower','displacement']
)
g.map(plt.scatter)

# %% [markdown]
# ## Customizing the PairGrid diagonols

# %%
g = sns.PairGrid(
    data=df,
    vars=['horsepower','displacement']
)
g.map_diag(plt.hist) # main diagonol 
g.map_offdiag(plt.scatter) # other diagonol

# %% [markdown]
# ## Pairplot

# %% [markdown]
# * shortcut for creating PairGrid

# %%
sns.pairplot(
    data=df,
    vars = ['horsepower', 'displacement'],
    kind = 'scatter', # main diagonol
    diag_kind='hist' # other diagonol 
)

# %% [markdown]
# ### customizing a pairplot

# %% [markdown]
# * pairplot with regression

# %%
sns.pairplot(
    data=df,
    vars = ['horsepower', 'displacement'],
    kind = 'reg', # main diagonol
    diag_kind='hist', # other diagonol 
    hue = 'model_year'
)

# %% [markdown]
# # Using JointGrid and jointplot

# %% [markdown]
# ## JointGrid

# %%
g = sns.JointGrid(
    data=df,
    x='horsepower',
    y='displacement'
)

g.plot(
    sns.regplot,
    sns.distplot 
    # sns.histplot
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## Advanced JointGrid

# %%
g = sns.JointGrid(
    data=df,
    x='horsepower',
    y='displacement'
)

g = g.plot_joint(sns.kdeplot)
g = g.plot_marginals(sns.kdeplot, shade =True)
# g= g.annotate(pearsonr)

# %% [markdown]
# ## Jointplot

# %%
sns.jointplot(
    data=df,
    x='horsepower',
    y='displacement',
    kind='hex'
)

# %% [markdown]
# # Selecting Seaborn Plots

# %% [markdown]
# * Univariate Distribution Analysis
#     * distplot() is the best place to start analysis of one variable
#     * rugplot() and kdeplot() can be useful alternatives (components of distplot)

# %% [markdown]
# * Regression Analysis : relationship between two variables
#     * lmplot() performs regression analysis and supports Facetting
#     * regplot and scatter plot are lmplot components
#     * best option to see linear relationships between data

# %% [markdown]
# * Categorical Plot
#     * factorplot represents the best option compared to FacetGrid

# %% [markdown]
# * Regression Analysis Plots Part 2
#     * pairplot and jointplot offer useful ways to see how two variables interact with eachother
